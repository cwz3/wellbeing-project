# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns

# %%
df = pd.read_csv("merged_kcal.csv")
display(df)


sns.regplot(data=df, x="Insufficient Activity (%)", y="Ladder score")
# Out:
#     Unnamed: 0          Country name  Alcoholic Beverages  Animal Products  \
# 0            0             Argentina               1.4354          14.9869
# 1            1             Australia               1.9783          15.6146
# 2            2               Austria               2.8161          15.6106
# 3            3            Bangladesh               0.0000           2.3695
# 4            4               Belgium               2.3089          14.1587
# 5            5                Brazil               1.4314          13.2061
# 6            6              Bulgaria               3.6782          12.2900
# 7            7                Canada               1.5748          12.6986
# 8            8                 Chile               1.5942          12.3547
# 9            9              Colombia               0.9856           8.8544
# 10          10               Croatia               2.7404          14.6911
# ...
